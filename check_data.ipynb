# %%
import numpy as np

stats = np.load("dataset/atc/atc1_normalization_stats.npz")

xy_min = stats["min"]   # shape (2,)
xy_max = stats["max"]   # shape (2,)

print("min:", xy_min)
print("max:", xy_max)
# Out:
# min: [-42.056 -30.586]
# max: [49.505 25.546]

# %%
# checkthe atc1_test_split.parquet file
import pandas as pd
df_test = pd.read_parquet("dataset/atc/debug/atc1_test_split.parquet")
print(df_test.head())
# Out:
#        epoch_time     person_id       x       y  speed  orientation
# 489  1.351038e+09  1.024921e+10  41.520 -21.222  1.336     3.639185
# 490  1.351038e+09  1.024921e+10  40.129 -20.230  1.346     2.374000
# 491  1.351038e+09  1.024921e+10  39.201 -19.902  0.980     2.675000
# 492  1.351038e+09  1.024921e+10  38.127 -19.603  1.091     2.577000
# 493  1.351038e+09  1.024921e+10  36.911 -19.165  1.224     2.585000
